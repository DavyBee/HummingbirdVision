# %% [markdown]
# This notebook follows the Ultralytics docs outline here: [Ultralytics Validation](https://docs.ultralytics.com/modes/val/).
#
# With this notebook, you can verify the statistics of your model. The output metrics will not be exact, as the pipeline here contains some post processing on the model outputs that Ultralytics does not do in the background of this validation. However, it should stand as a fairly good guide.
#
# Run the code below to get an indication of the model precision, recall, and Mean-Average-Precision (MAP) across different confidence levels.
#
# Important to note, the precision listed by the validate function is not totally indicitive of the precision of the model on hummingbirds. Rather, it combines the precision for hummingbirds with the precision for detecting a background. Usually, the bird precision is lower than the background precision, but you can manually calculate the precision by looking at the confusion matrix generated by the process.

# %%
from ultralytics import YOLO

model_path = 'model_weights/YOLO.pt'
data_path = 'dataset/data.yaml'

model = YOLO(model_path)

model.val(data = data_path, project = 'parent_folder_name', name = 'folder_name')
# Out:
# Ultralytics 8.3.146 🚀 Python-3.13.2 torch-2.7.0 CPU (Apple M1 Pro)
# YOLO11l summary (fused): 190 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
# val: Fast image access ✅ (ping: 0.2±0.2 ms, read: 314.8±100.6 MB/s, size: 79.2 KB)
# val: Scanning /Users/default/Desktop/HummingbirdVision/dataset/valid/labels.cache... 1078 images, 82 backgrounds, 0 corrupt: 100%|██████████| 1078/1078 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/68 [00:08<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       4 data_path = 'dataset/data.yaml'
#       6 model = YOLO(model_path)
# ----> 8 model.val(data = data_path, project = 'parent_folder_name', name = 'folder_name')
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/model.py:633, in Model.val(self, validator, **kwargs)
#     630 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     632 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 633 validator(model=self.model)
#     634 self.metrics = validator.metrics
#     635 return validator.metrics
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/validator.py:214, in BaseValidator.__call__(self, trainer, model)
#     212 # Inference
#     213 with dt[1]:
# --> 214     preds = model(batch["img"], augment=augment)
#     216 # Loss
#     217 with dt[2]:
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/autobackend.py:636, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     634 # PyTorch
#     635 if self.pt or self.nn_module:
# --> 636     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     638 # TorchScript
#     639 elif self.jit:
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     136 if isinstance(x, dict):  # for cases of training and validating while training.
#     137     return self.loss(x, *args, **kwargs)
# --> 138 return self.predict(x, *args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/tasks.py:156, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     154 if augment:
#     155     return self._predict_augment(x)
# --> 156 return self._predict_once(x, profile, visualize, embed)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/tasks.py:179, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     177 if profile:
#     178     self._profile_one_layer(m, x, dt)
# --> 179 x = m(x)  # run
#     180 y.append(x if m.i in self.save else None)  # save output
#     181 if visualize:
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/modules/block.py:317, in C2f.forward(self, x)
#     315 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     316     """Forward pass through C2f layer."""
# --> 317     y = list(self.cv1(x).chunk(2, 1))
#     318     y.extend(m(y[-1]) for m in self.m)
#     319     return self.cv2(torch.cat(y, 1))
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/modules/conv.py:92, in Conv.forward_fuse(self, x)
#      82 def forward_fuse(self, x):
#      83     """
#      84     Apply convolution and activation without batch normalization.
#      85
#    (...)     90         (torch.Tensor): Output tensor.
#      91     """
# ---> 92     return self.act(self.conv(x))
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %%
from ultralytics import RTDETR
## similar code below
