# %% [markdown]
# ## Modify these parameters to change the model behavior:
#
#
# `conf` &nbsp;&nbsp;(default = `0.35`)\
# &nbsp;\
# This parameter adjusts what confidence the model must have in an output being a hummingbird for it to be returned. Lower `conf` scores will output more potential birds, but will likely give way more false positives. On sample data, I found `conf = 0.35` to be a good mix of not returning too many objects, but not missing most birds either.
# &nbsp; <br>
# &nbsp;
#
# `iou`&nbsp;&nbsp; (default = `0.001`)\
# &nbsp;\
# This parameter adjusts the Intersection Over Union (IOU) setting, which modifies the outputs by applying Non-Maximum-Supression (NMS). A more strict (lower) `iou` value will ensure that bounding boxes which overlap at a certain threshold will be disregarded as they are likely referring to the same object. Since there is most often only 1 bird in frame in the sample data, I have found setting the `iou` to a tiny value around `iou = 0.001` is best - this returns only one bounding box around the bird if the hummingbird is present. Adjust to higher values if you think multiple birds will often be in frame.
# &nbsp; <br>
# &nbsp;
#
# `batch` &nbsp;&nbsp;(default = `32`)\
# &nbsp;\
# Batching is when the model deals with multiple inputs at a time which can increase inference speed in most cases. By default this value is `32`, which benchmarked the best on my testing with a low power GPU (actually just Apple's MPS cores). Increasing `batch` increases memory consmption though, so you may run into memory overload issues - adjust as necessary. The average time per frame is printed, so look to see how increasing/decreasing batch is optimized for your machine.
# &nbsp; <br>
# &nbsp;

# %% [markdown]
# ## Modify these parameters to change input/output
#
# `data_path` &nbsp;&nbsp;(default = `data`)\
# &nbsp;\
# This is the folder where the model will read from to get the data to run on. It can be any folder in the root folder. By default, it will read in from the `data` folder. It is recommended that you place all your data here. You can either place one video, multiple videos, or individual frames in this folder. Relative paths are accepted.
# &nbsp; <br>
# &nbsp;
#
# `results_path` &nbsp;&nbsp;(default = `results`)\
# &nbsp;\
# This is where the output will be saved. It can be any folder in the root folder. By default, it will save to a results folder (and make one if it does not exist). Each job will be placed in a separate folder labeled job#. You do not need to provide this parameter, and it is actually recommended that you do not so that all jobs are saved to `results`. Relative paths are accepted.
# &nbsp; <br>
# &nbsp;
#
# `save_frames` &nbsp;&nbsp;(default = `True`)\
# &nbsp;\
# Set this to `True` you want to save the output frames that contain predicted birds from data. Make it `False` if you want to not save these frames
# &nbsp; <br>
# &nbsp;
#
# `save_frames_csv` &nbsp;&nbsp;(default = `True`)\
# &nbsp;\
# Set this to `True` if you want to save the csv_file with prediction results per video (`frames.csv`). If you are passing multiple videos, multiple `frames.csv` are created in each folder corresponding to the video results. Set it to `False` if you want to skip saving these files. This only affects saving a frames.csv when you are passing video files, not the `frames.csv` when passing multiple images. It also doesn't affect saving the `all_vid_data.csv` when passing multiple video files.
# &nbsp; <br>
# &nbsp;
#
# `save_all_csv` &nbsp;&nbsp;(default = `True`)\
# &nbsp;\
# Set this to `True` if you want to save the csv_file with prediction results for all combined videos (`all_vid_data.csv`) when passing multiple videos and for saving `frames.csv` when passing multiple images. Set it to `False` to avoid saving these files.

# %%
# Modify Parameters Here
# Commong alternatives in comments above

from backend import ModelConfig

#example usage
parameters = ModelConfig(
    conf=0.45,
    iou=0.001,
    batch_size=32,
    data_path='data_test',
)

# %% [markdown]
# ## Comparing Models:
# YOLO is 2x faster, but very slightly less precise than RTDETR (~1-5%). Use YOLO if you want to get results back fastest, with super high precision. Use RTDETR if you want the absolute best of the best results (according to tests run on sample data). However, depending on your GPU, it can take 2x time of YOLO.

# %% [markdown]
# ## Run this code to predict hummingbirds in all the videos in the `data` folder (or whatever folder you specified) with the YOLO model

# %%
from backend import pipeline

# returns a dataframe that is the same as 
results = pipeline.yolo_pipeline(parameters)
print(results)
# Out:
# Processing Video: Trimmed.mp4
# Processing batch 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 from backend import pipeline
#       3 # returns a dataframe that is the same as
# ----> 4 results = pipeline.yolo_pipeline(parameters)
#       5 print(results)
#
# File ~/Desktop/HummingbirdVision/src/backend/pipeline.py:26, in yolo_pipeline(config)
#      24 def yolo_pipeline(config):
#      25     model = YoloModel(config)
# ---> 26     pipeline(model)
#
# File ~/Desktop/HummingbirdVision/src/backend/pipeline.py:17, in pipeline(model)
#      15     processor.process_imgs(model, images)
#      16 if videos:
# ---> 17     processor.process_videos(model, videos)
#      18 all_data = processor.get_all_data(images, videos)
#      20 if images and videos and all_data:
#
# File ~/Desktop/HummingbirdVision/src/backend/processor.py:49, in process_videos(model, videos)
#      46 all_vid_rows = []
#      48 for vid in videos:
# ---> 49     print(f'Processing Video: {vid.name}')
#      50     vid_rows_for_df = process_vid(model, vid)
#      51     all_vid_rows.extend(vid_rows_for_df)
#
# File ~/Desktop/HummingbirdVision/src/backend/processor.py:36, in process_vid(model, vid)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/HummingbirdVision/src/backend/processor.py:16, in process_batches(model, batch_gen, output_path)
#      13 print(f'Processing batch {i}')
#      14 start_time = time.perf_counter()
# ---> 16 results = model.predict(batch)
#      17 ## saving individual frames in postprocessor, returning list of results for df
#      18 batch_rows_for_df = postprocessor.handle_results(results, output_path, i * model.config.batch_size, model.config)
#
# File ~/Desktop/HummingbirdVision/src/backend/model.py:23, in UltralyticsModel.predict(self, batch_tup)
#      20 fnames = list(fnames)
#      21 batch = list(batch)
# ---> 23 results = self.model.predict(
#      24             source=batch,
#      25             verbose=False,
#      26             conf=self.config.conf,
#      27             iou=self.config.iou,
#      28             batch=self.config.batch_size,
#      29             device='mps'
#      30         )
#      32 #making dict to store file name, overhead low
#      33 for name, result in zip(fnames, results):
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/model.py:555, in Model.predict(self, source, stream, predictor, **kwargs)
#     553 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554     self.predictor.set_prompts(prompts)
# --> 555 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/predictor.py:227, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     225     return self.stream_inference(source, model, *args, **kwargs)
#     226 else:
# --> 227     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/predictor.py:330, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     328 # Inference
#     329 with profilers[1]:
# --> 330     preds = self.inference(im, *args, **kwargs)
#     331     if self.args.embed:
#     332         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#     176 """Run inference on a given image using the specified model and arguments."""
#     177 visualize = (
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     179     if self.args.visualize and (not self.source_type.tensor)
#     180     else False
#     181 )
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/autobackend.py:636, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     634 # PyTorch
#     635 if self.pt or self.nn_module:
# --> 636     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     638 # TorchScript
#     639 elif self.jit:
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     136 if isinstance(x, dict):  # for cases of training and validating while training.
#     137     return self.loss(x, *args, **kwargs)
# --> 138 return self.predict(x, *args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/tasks.py:156, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     154 if augment:
#     155     return self._predict_augment(x)
# --> 156 return self._predict_once(x, profile, visualize, embed)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/tasks.py:179, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     177 if profile:
#     178     self._profile_one_layer(m, x, dt)
# --> 179 x = m(x)  # run
#     180 y.append(x if m.i in self.save else None)  # save output
#     181 if visualize:
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/upsampling.py:172, in Upsample.forward(self, input)
#     171 def forward(self, input: Tensor) -> Tensor:
# --> 172     return F.interpolate(
#     173         input,
#     174         self.size,
#     175         self.scale_factor,
#     176         self.mode,
#     177         self.align_corners,
#     178         recompute_scale_factor=self.recompute_scale_factor,
#     179     )
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/functional.py:4649, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    4647     return torch._C._nn.upsample_nearest1d(input, output_size, scale_factors)
#    4648 if input.dim() == 4 and mode == "nearest":
# -> 4649     return torch._C._nn.upsample_nearest2d(input, output_size, scale_factors)
#    4650 if input.dim() == 5 and mode == "nearest":
#    4651     return torch._C._nn.upsample_nearest3d(input, output_size, scale_factors)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Run this code to predict hummingbirds in all the videos in the `data` folder (or whatever folder you specified) with the RTDETR model

# %%
from backend import pipeline

results = pipeline.detr_pipeline(parameters)
# Out:
# Processing Video: Trimmed.mp4
# Processing batch 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from backend import pipeline
# ----> 3 pipeline.detr_pipeline(parameters)
#
# File ~/Desktop/HummingbirdVision/src/backend/pipeline.py:30, in detr_pipeline(config)
#      28 def detr_pipeline(config):
#      29     model = DetrModel(config)
# ---> 30     pipeline(model)
#
# File ~/Desktop/HummingbirdVision/src/backend/pipeline.py:17, in pipeline(model)
#      15     processor.process_imgs(model, images)
#      16 if videos:
# ---> 17     processor.process_videos(model, videos)
#      18 all_data = processor.get_all_data(images, videos)
#      20 if images and videos and all_data:
#
# File ~/Desktop/HummingbirdVision/src/backend/processor.py:49, in process_videos(model, videos)
#      47 for vid in videos:
#      48     print(f'Processing Video: {vid.name}')
# ---> 49     vid_rows_for_df = process_vid(model, vid)
#      50     all_vid_rows.extend(vid_rows_for_df)
#      52 if all_vid_rows:
#
# File ~/Desktop/HummingbirdVision/src/backend/processor.py:36, in process_vid(model, vid)
#      33 output_path.mkdir(exist_ok = True)
#      34 batch_gen = preprocessor.get_batch_vid(vid, batch_size=model.config.batch_size)
# ---> 36 vid_rows_for_df, times = process_batches(model, batch_gen, output_path)
#      38 if times:
#      39     avg_time_per_frame = statistics.fmean(times) * 1000 / model.config.batch_size
#
# File ~/Desktop/HummingbirdVision/src/backend/processor.py:16, in process_batches(model, batch_gen, output_path)
#      13 print(f'Processing batch {i}')
#      14 start_time = time.perf_counter()
# ---> 16 results = model.predict(batch)
#      17 ## saving individual frames in postprocessor, returning list of results for df
#      18 batch_rows_for_df = postprocessor.handle_results(results, output_path, i * model.config.batch_size, model.config)
#
# File ~/Desktop/HummingbirdVision/src/backend/model.py:23, in UltralyticsModel.predict(self, batch_tup)
#      20 fnames = list(fnames)
#      21 batch = list(batch)
# ---> 23 results = self.model.predict(
#      24             source=batch,
#      25             verbose=False,
#      26             conf=self.config.conf,
#      27             iou=self.config.iou,
#      28             batch=self.config.batch_size,
#      29         )
#      31 #making dict to store file name, overhead low
#      32 for name, result in zip(fnames, results):
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/model.py:555, in Model.predict(self, source, stream, predictor, **kwargs)
#     553 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554     self.predictor.set_prompts(prompts)
# --> 555 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/predictor.py:227, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     225     return self.stream_inference(source, model, *args, **kwargs)
#     226 else:
# --> 227     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/predictor.py:330, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     328 # Inference
#     329 with profilers[1]:
# --> 330     preds = self.inference(im, *args, **kwargs)
#     331     if self.args.embed:
#     332         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/engine/predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#     176 """Run inference on a given image using the specified model and arguments."""
#     177 visualize = (
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     179     if self.args.visualize and (not self.source_type.tensor)
#     180     else False
#     181 )
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/autobackend.py:636, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     634 # PyTorch
#     635 if self.pt or self.nn_module:
# --> 636     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     638 # TorchScript
#     639 elif self.jit:
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     136 if isinstance(x, dict):  # for cases of training and validating while training.
#     137     return self.loss(x, *args, **kwargs)
# --> 138 return self.predict(x, *args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/tasks.py:816, in RTDETRDetectionModel.predict(self, x, profile, visualize, batch, augment, embed)
#     814 if profile:
#     815     self._profile_one_layer(m, x, dt)
# --> 816 x = m(x)  # run
#     817 y.append(x if m.i in self.save else None)  # save output
#     818 if visualize:
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/modules/block.py:188, in HGBlock.forward(self, x)
#     186 y = [x]
#     187 y.extend(m(y[-1]) for m in self.m)
# --> 188 y = self.ec(self.sc(torch.cat(y, 1)))
#     189 return y + x if self.add else y
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/ultralytics/nn/modules/conv.py:92, in Conv.forward_fuse(self, x)
#      82 def forward_fuse(self, x):
#      83     """
#      84     Apply convolution and activation without batch normalization.
#      85
#    (...)     90         (torch.Tensor): Output tensor.
#      91     """
# ---> 92     return self.act(self.conv(x))
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/miniconda3/envs/buh/lib/python3.13/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
